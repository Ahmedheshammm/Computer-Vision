# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Define constants
CLASS_NAMES = ['CaS', 'CoS', 'Gum', 'MC', 'OC', 'OLP', 'OT']
IMG_SIZE = 224
BATCH_SIZE = 32

# Set up path
base_dir = '/kaggle/input/teeth-dataset/Teeth_Dataset'
train_dir = os.path.join(base_dir, 'Training')
valid_dir = os.path.join(base_dir, 'Validation')
test_dir = os.path.join(base_dir, 'Testing')

# Verify paths and data
print("Available directories:")
print(f"Training: {os.path.exists(train_dir)}")
print(f"Validation: {os.path.exists(valid_dir)}")
print(f"Testing: {os.path.exists(test_dir)}")
# Out:
# Available directories:
# Training: True
# Validation: True
# Testing: True

# %%
# Count images in each directory
def count_images(directory):
    counts = {}
    for class_name in CLASS_NAMES:
        class_dir = os.path.join(directory, class_name)
        if os.path.exists(class_dir):
            counts[class_name] = len(os.listdir(class_dir))
    return counts

print("\nImage counts:")
print("Training:", count_images(train_dir))
print("Validation:", count_images(valid_dir))
print("Testing:", count_images(test_dir))
# Out:
# Image counts:
# Training: {'CaS': 480, 'CoS': 450, 'Gum': 360, 'MC': 540, 'OC': 324, 'OLP': 540, 'OT': 393}
# Validation: {'CaS': 160, 'CoS': 149, 'Gum': 120, 'MC': 180, 'OC': 108, 'OLP': 180, 'OT': 131}
# Testing: {'CaS': 160, 'CoS': 149, 'Gum': 120, 'MC': 180, 'OC': 108, 'OLP': 180, 'OT': 131}

# %%
# Create data generators
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# Create generators
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    shuffle=True
)

validation_generator = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    shuffle=False
)
# Out:
# Found 3087 images belonging to 7 classes.
# Found 1028 images belonging to 7 classes.
# Found 1028 images belonging to 7 classes.

# %%
# Create base model
base_model = EfficientNetB3(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# Create model
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, 
                activation='relu',
                kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Dropout(0.4),
    layers.Dense(len(CLASS_NAMES), activation='softmax')
])

# Compile model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy',
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')]
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Train the model
initial_history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=40,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=8,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=5
        )
    ]
)
# Out:
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 230s 1s/step - accuracy: 0.5180 - loss: 3.8489 - precision: 0.5921 - recall: 0.4456 - val_accuracy: 0.1819 - val_loss: 3.8538 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 357ms/step - accuracy: 0.8928 - loss: 1.9946 - precision: 0.9195 - recall: 0.8740 - val_accuracy: 0.1556 - val_loss: 3.1893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 351ms/step - accuracy: 0.9066 - loss: 1.3313 - precision: 0.9210 - recall: 0.8902 - val_accuracy: 0.1245 - val_loss: 2.8816 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 355ms/step - accuracy: 0.9458 - loss: 0.8080 - precision: 0.9538 - recall: 0.9376 - val_accuracy: 0.2111 - val_loss: 2.7352 - val_precision: 0.3105 - val_recall: 0.0574 - learning_rate: 0.0010
# Epoch 5/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 38s 364ms/step - accuracy: 0.9440 - loss: 0.5377 - precision: 0.9551 - recall: 0.9414 - val_accuracy: 0.4125 - val_loss: 2.2475 - val_precision: 0.4526 - val_recall: 0.3667 - learning_rate: 0.0010
# Epoch 6/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 356ms/step - accuracy: 0.9651 - loss: 0.3705 - precision: 0.9691 - recall: 0.9594 - val_accuracy: 0.6488 - val_loss: 1.5373 - val_precision: 0.7068 - val_recall: 0.6167 - learning_rate: 0.0010
# Epoch 7/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 354ms/step - accuracy: 0.9701 - loss: 0.2644 - precision: 0.9726 - recall: 0.9655 - val_accuracy: 0.7325 - val_loss: 1.0878 - val_precision: 0.7515 - val_recall: 0.7150 - learning_rate: 0.0010
# Epoch 8/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 353ms/step - accuracy: 0.9461 - loss: 0.2940 - precision: 0.9483 - recall: 0.9423 - val_accuracy: 0.9533 - val_loss: 0.2784 - val_precision: 0.9576 - val_recall: 0.9455 - learning_rate: 0.0010
# Epoch 9/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 355ms/step - accuracy: 0.9600 - loss: 0.2242 - precision: 0.9660 - recall: 0.9555 - val_accuracy: 0.9300 - val_loss: 0.3819 - val_precision: 0.9341 - val_recall: 0.9241 - learning_rate: 0.0010
# Epoch 10/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 36s 347ms/step - accuracy: 0.9609 - loss: 0.2209 - precision: 0.9649 - recall: 0.9546 - val_accuracy: 0.8765 - val_loss: 0.5315 - val_precision: 0.8901 - val_recall: 0.8667 - learning_rate: 0.0010
# Epoch 11/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 358ms/step - accuracy: 0.9621 - loss: 0.1867 - precision: 0.9675 - recall: 0.9609 - val_accuracy: 0.7928 - val_loss: 0.8163 - val_precision: 0.8076 - val_recall: 0.7879 - learning_rate: 0.0010
# Epoch 12/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 356ms/step - accuracy: 0.9727 - loss: 0.1630 - precision: 0.9761 - recall: 0.9661 - val_accuracy: 0.8988 - val_loss: 0.4757 - val_precision: 0.9061 - val_recall: 0.8920 - learning_rate: 0.0010
# Epoch 13/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 356ms/step - accuracy: 0.9618 - loss: 0.1905 - precision: 0.9667 - recall: 0.9608 - val_accuracy: 0.9854 - val_loss: 0.1125 - val_precision: 0.9854 - val_recall: 0.9835 - learning_rate: 0.0010
# Epoch 14/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 350ms/step - accuracy: 0.9714 - loss: 0.1586 - precision: 0.9772 - recall: 0.9679 - val_accuracy: 0.9669 - val_loss: 0.1936 - val_precision: 0.9715 - val_recall: 0.9621 - learning_rate: 0.0010
# Epoch 15/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 36s 350ms/step - accuracy: 0.9747 - loss: 0.1652 - precision: 0.9788 - recall: 0.9709 - val_accuracy: 0.9767 - val_loss: 0.1843 - val_precision: 0.9766 - val_recall: 0.9757 - learning_rate: 0.0010
# Epoch 16/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 354ms/step - accuracy: 0.9719 - loss: 0.1483 - precision: 0.9739 - recall: 0.9651 - val_accuracy: 0.8434 - val_loss: 0.8149 - val_precision: 0.8536 - val_recall: 0.8337 - learning_rate: 0.0010
# Epoch 17/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 350ms/step - accuracy: 0.9684 - loss: 0.1677 - precision: 0.9703 - recall: 0.9637 - val_accuracy: 0.9689 - val_loss: 0.1759 - val_precision: 0.9698 - val_recall: 0.9669 - learning_rate: 0.0010
# Epoch 18/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 358ms/step - accuracy: 0.9749 - loss: 0.1278 - precision: 0.9787 - recall: 0.9729 - val_accuracy: 0.9883 - val_loss: 0.1001 - val_precision: 0.9883 - val_recall: 0.9883 - learning_rate: 0.0010
# Epoch 19/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 36s
- val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 2.0000e-04
# Epoch 34/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 351ms/step - accuracy: 0.9947 - loss: 0.0283 - precision: 0.9948 - recall: 0.9947 - val_accuracy: 0.9951 - val_loss: 0.0336 - val_precision: 0.9951 - val_recall: 0.9951 - learning_rate: 2.0000e-04
# Epoch 35/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 351ms/step - accuracy: 0.9947 - loss: 0.0314 - precision: 0.9954 - recall: 0.9947 - val_accuracy: 0.9961 - val_loss: 0.0312 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 2.0000e-04
# Epoch 36/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 36s 349ms/step - accuracy: 0.9961 - loss: 0.0237 - precision: 0.9961 - recall: 0.9960 - val_accuracy: 0.9961 - val_loss: 0.0249 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 2.0000e-04
# Epoch 37/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 36s 349ms/step - accuracy: 0.9928 - loss: 0.0290 - precision: 0.9934 - recall: 0.9927 - val_accuracy: 0.9961 - val_loss: 0.0229 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 2.0000e-04
# Epoch 38/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 354ms/step - accuracy: 0.9943 - loss: 0.0295 - precision: 0.9943 - recall: 0.9943 - val_accuracy: 0.9961 - val_loss: 0.0298 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 2.0000e-04
# Epoch 39/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 353ms/step - accuracy: 0.9973 - loss: 0.0222 - precision: 0.9973 - recall: 0.9964 - val_accuracy: 0.9961 - val_loss: 0.0287 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 2.0000e-04
# Epoch 40/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 37s 357ms/step - accuracy: 0.9958 - loss: 0.0217 - precision: 0.9958 - recall: 0.9958 - val_accuracy: 0.9971 - val_loss: 0.0247 - val_precision: 0.9971 - val_recall: 0.9961 - learning_rate: 2.0000e-04

# %%
# Prepare model for fine-tuning
base_model = model.layers[0]
base_model.trainable = True

# Freeze all layers except the last 15
for layer in base_model.layers[:-15]:
    layer.trainable = False

# Recompile model with lower learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy',
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')]
)

# Fine-tune the model
fine_tune_history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=20,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=6,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=4,
            min_lr=1e-7
        )
    ]
)
# Out:
# Epoch 1/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 600ms/step - accuracy: 0.9953 - loss: 0.0181 - precision: 0.9973 - recall: 0.9953 - val_accuracy: 0.9961 - val_loss: 0.0211 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 2/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - accuracy: 0.9996 - loss: 0.0137 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9961 - val_loss: 0.0208 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 3/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 332ms/step - accuracy: 0.9983 - loss: 0.0138 - precision: 0.9983 - recall: 0.9982 - val_accuracy: 0.9971 - val_loss: 0.0205 - val_precision: 0.9971 - val_recall: 0.9971 - learning_rate: 1.0000e-05
# Epoch 4/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - accuracy: 0.9987 - loss: 0.0164 - precision: 0.9987 - recall: 0.9987 - val_accuracy: 0.9971 - val_loss: 0.0202 - val_precision: 0.9971 - val_recall: 0.9971 - learning_rate: 1.0000e-05
# Epoch 5/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 36s 347ms/step - accuracy: 0.9987 - loss: 0.0125 - precision: 0.9987 - recall: 0.9981 - val_accuracy: 0.9961 - val_loss: 0.0200 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 6/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 335ms/step - accuracy: 0.9983 - loss: 0.0112 - precision: 0.9983 - recall: 0.9983 - val_accuracy: 0.9961 - val_loss: 0.0198 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 7/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 331ms/step - accuracy: 0.9984 - loss: 0.0128 - precision: 0.9984 - recall: 0.9981 - val_accuracy: 0.9961 - val_loss: 0.0194 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 8/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 335ms/step - accuracy: 0.9989 - loss: 0.0110 - precision: 0.9989 - recall: 0.9989 - val_accuracy: 0.9961 - val_loss: 0.0191 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 9/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - accuracy: 0.9987 - loss: 0.0111 - precision: 0.9987 - recall: 0.9987 - val_accuracy: 0.9961 - val_loss: 0.0190 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 10/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 329ms/step - accuracy: 0.9968 - loss: 0.0119 - precision: 0.9968 - recall: 0.9968 - val_accuracy: 0.9971 - val_loss: 0.0189 - val_precision: 0.9971 - val_recall: 0.9971 - learning_rate: 1.0000e-05
# Epoch 11/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 337ms/step - accuracy: 0.9977 - loss: 0.0114 - precision: 0.9980 - recall: 0.9977 - val_accuracy: 0.9971 - val_loss: 0.0187 - val_precision: 0.9971 - val_recall: 0.9971 - learning_rate: 1.0000e-05
# Epoch 12/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 36s 343ms/step - accuracy: 0.9981 - loss: 0.0101 - precision: 0.9983 - recall: 0.9981 - val_accuracy: 0.9961 - val_loss: 0.0181 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 13/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - accuracy: 0.9999 - loss: 0.0085 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9961 - val_loss: 0.0181 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 14/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 332ms/step - accuracy: 0.9951 - loss: 0.0157 - precision: 0.9951 - recall: 0.9951 - val_accuracy: 0.9961 - val_loss: 0.0182 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 15/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - accuracy: 0.9986 - loss: 0.0092 - precision: 0.9986 - recall: 0.9986 - val_accuracy: 0.9961 - val_loss: 0.0176 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 16/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 333ms/step - accuracy: 0.9984 - loss: 0.0101 - precision: 0.9984 - recall: 0.9984 - val_accuracy: 0.9961 - val_loss: 0.0175 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 17/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 331ms/step - accuracy: 0.9985 - loss: 0.0100 - precision: 0.9985 - recall: 0.9985 - val_accuracy: 0.9971 - val_loss: 0.0172 - val_precision: 0.9971 - val_recall: 0.9971 - learning_rate: 1.0000e-05
# Epoch 18/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 333ms/step - accuracy: 0.9984 - loss: 0.0094 - precision: 0.9984 - recall: 0.9984 - val_accuracy: 0.9961 - val_loss: 0.0176 - val_precision: 0.9961 - val_recall: 0.9961 - learning_rate: 1.0000e-05
# Epoch 19/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 331ms/step - accuracy: 0.9989 - loss: 0.0079 - precision: 0.9989 - recall: 0.9989 - val_accuracy: 0.9971 - val_loss: 0.0172 - val_precision: 0.9971 - val_recall: 0.9971 - learning_rate: 1.0000e-05
# Epoch 20/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - accuracy: 0.9992 - loss: 0.0069 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9971 - val_loss: 0.0169 - val_precision: 0.9971 - val_recall: 0.9971 - learning_rate: 1.0000e-05

# %%
# Evaluate model
test_results = model.evaluate(test_generator)
print("\nTest Results:")
print(f"Test Loss: {test_results[0]:.4f}")
print(f"Test Accuracy: {test_results[1]:.4f}")
print(f"Test Precision: {test_results[2]:.4f}")
print(f"Test Recall: {test_results[3]:.4f}")

# Save model
model.save('teeth_classification_model.h5')
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0054 - precision: 1.0000 - recall: 1.0000
#
# Test Results:
# Test Loss: 0.0063
# Test Accuracy: 1.0000
# Test Precision: 1.0000
# Test Recall: 1.0000

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (5.16.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (22.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.115.8)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.7.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.7.0)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.10.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (11.0.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.11.0a1)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.9.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.45.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.7.0->gradio) (2024.9.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.7.0->gradio) (14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.28.1->gradio) (3.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.0->gradio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.0->gradio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.0->gradio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.0->gradio) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.0->gradio) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.0->gradio) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.28.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (2.28.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0,>=1.0->gradio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0,>=1.0->gradio) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<3.0,>=1.0->gradio) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<3.0,>=1.0->gradio) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.3.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<3.0,>=1.0->gradio) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
import os
print("Files in working directory:", os.listdir("/kaggle/working/"))
# Out:
# Files in working directory: ['app.py', 'teeth_classification_model.h5', '.virtual_documents']

# %%
import gradio as gr
import tensorflow as tf
import numpy as np
from PIL import Image

# Load the trained model
model = tf.keras.models.load_model("/kaggle/working/teeth_classification_model.h5")

CLASS_NAMES = ['CaS', 'CoS', 'Gum', 'MC', 'OC', 'OLP', 'OT']

def predict_teeth_disease(img):
    img = img.resize((224, 224))  # Resize image
    img_array = np.array(img) / 255.0  # Normalize
    img_array = np.expand_dims(img_array, axis=0)  # Expand dimensions for model
    prediction = model.predict(img_array)[0]
    return {CLASS_NAMES[i]: float(prediction[i]) for i in range(len(CLASS_NAMES))}

# Launch the Gradio interface
interface = gr.Interface(
    fn=predict_teeth_disease,
    inputs=gr.Image(type="pil"),
    outputs=gr.Label(),
    title="Teeth Disease Classification",
    description="Upload an image to classify different types of teeth conditions."
)

interface.launch(share=True)  # Generates a public URL for access
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://dc93da07246ac028ca.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://dc93da07246ac028ca.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
